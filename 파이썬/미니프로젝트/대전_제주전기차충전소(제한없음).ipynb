# %% [markdown]
# 서울,경기 / 대전,제주 / 충남, 인천, 부산
# 충전소 비율, 총 대수

# %%
import pandas as pd

# %%
# 대전 총 전기차 충전소 개수 3194
# 제주 총 전기차 충전소 개수 5152
# 참고 사이트 : https://www.ev.or.kr/evmlocal?sido=%EB%8C%80%EC%A0%84%EA%B4%91%EC%97%AD%EC%8B%9C (대전)
#               https://www.ev.or.kr/evmlocal?sido=%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84 (제주)

# %%
file_path = './충전소_리스트.csv'
Elec_list = pd.read_csv(file_path)
Elec_list.head()
# Out:
#              운영기관                          충전소  충전기ID 충전기타입     지역   시군구  \
# 0  환경부(한국자동차환경협회)                  신북보건지소공영주차장     21  DC콤보  전라남도   영암군
# 1  환경부(한국자동차환경협회)                  신북보건지소공영주차장     22  DC콤보  전라남도   영암군
# 2  환경부(한국자동차환경협회)   한국생산기술연구원 대경본부바이오메디칼생산기술센터      1  DC콤보  경상북도   영천시
# 3  환경부(한국자동차환경협회)   한국생산기술연구원 대경본부바이오메디칼생산기술센터      2  DC콤보  경상북도   영천시
# 4  환경부(한국자동차환경협회)                (구)거진수산센터 주차장     11  DC콤보   강원도   고성군
#
#                        주소     이용가능시간 이용자 제한        급속충전량   비고
# 0  전라남도 영암군 신북면 간은정로 21-7  24시간 이용가능    NaN  급속(200kW동시)  NaN
# 1  전라남도 영암군 신북면 간은정로 21-7  24시간 이용가능    NaN  급속(200kW동시)  NaN
# 2         경상북도 영천시 양호길 59  24시간 이용가능    NaN  급속(100kW단독)  NaN
# 3         경상북도 영천시 양호길 59  24시간 이용가능    NaN  급속(100kW단독)  NaN
# 4   강원도 고성군 거진읍 거진리 22-93  24시간 이용가능    NaN  급속(200kW동시)  NaN

# %%
# 이용자한 NaN >> 제한없음으로 변경
Elec_list['이용자 제한'] = Elec_list['이용자 제한'].fillna('제한없음')

# %%
# 지역명 뒤 띄어쓰기 제거
Elec_list['지역'] = Elec_list['지역'].str.strip()

# %%
Elec_list['지역'].unique()
# Out:
# array(['전라남도', '경상북도', '강원도', '경상남도', '광주광역시', '전라북도', '서울특별시', '충청남도',
#        '경기도', '충청북도', '대전광역시', '세종특별자치시', '대구광역시', '부산광역시', '제주특별자치도',
#        '인천광역시', '울산광역시'], dtype=object)

# %%
Elec_list_DJ = Elec_list[Elec_list['지역'] == '대전광역시']

# %%
Elec_list_DJ
# Out:
#                   운영기관         충전소  충전기ID            충전기타입     지역   시군구  \
# 41      환경부(한국자동차환경협회)      KT가정빌딩      1  DC차데모+AC3상+DC콤보  대전광역시  유성구
# 100     환경부(한국자동차환경협회)  가수원동행정복지센터      1             DC콤보  대전광역시   서구
# 133     환경부(한국자동차환경협회)  갈마2동 공영주차장      1             DC콤보  대전광역시   서구
# 134     환경부(한국자동차환경협회)       갈마도서관      1  DC차데모+AC3상+DC콤보  대전광역시   서구
# 550     환경부(한국자동차환경협회)    관저2동주민센터      1  DC차데모+AC3상+DC콤보  대전광역시   서구
# ...                ...         ...    ...              ...    ...   ...
# 120980             에너넷     대전보건대학교     32             AC완속  대전광역시   동구
# 120981             에너넷     대전보건대학교     33             AC완속  대전광역시   동구
# 120982             에너넷     대전보건대학교     34             AC완속  대전광역시   동구
# 120983             에너넷     대전보건대학교     35             AC완속  대전광역시   동구
# 120992           한화솔루션    기린아이에스빌딩      1             AC완속  대전광역시  유성구
#
#                                               주소     이용가능시간 이용자 제한  \
# ...

# %%
# 대전에 있는 전기충전소 이용자 제한이 없는 곳만 추출
Elec_list_DJ = Elec_list_DJ[Elec_list_DJ['이용자 제한'] == '제한없음']

# %%
Elec_list_DJ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1332 entries, 41 to 120992
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   운영기관    1332 non-null   object
#  1   충전소     1332 non-null   object
#  2   충전기ID   1332 non-null   int64
#  3   충전기타입   1332 non-null   object
#  4   지역      1332 non-null   object
#  5   시군구     1330 non-null   object
#  6   주소      1332 non-null   object
#  7   이용가능시간  1266 non-null   object
#  8   이용자 제한  1332 non-null   object
#  9   급속충전량   129 non-null    object
#  10  비고      268 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 124.9+ KB

# %%
Elec_list_DJ[Elec_list_DJ.duplicated()]  # 대전 중복 X
# Out:
# Empty DataFrame
# Columns: [운영기관, 충전소, 충전기ID, 충전기타입, 지역, 시군구, 주소, 이용가능시간, 이용자 제한, 급속충전량, 비고]
# Index: []

# %%
Elec_list_DJ['시군구'].unique()
# Out:
# array(['유성구 ', '서구 ', '대덕구 ', '중구 ', '동구 ', nan], dtype=object)

# %%
Elec_list_DJ['주소'].unique()
# Out:
# array(['대전광역시 유성구 가정로 168 입구 경비실 앞 주차장', '대전광역시 서구 가수원로 105',
#        '대전광역시 서구 갈마중로 30번길 15-5', '대전광역시 서구 갈마동 427-20 ',
#        '대전광역시 서구 관저동 1104', '대전광역시 서구 관저동 1199', '대전광역시 서구 관저동 1510',
#        '대전광역시 유성구 교촌동 636-1', '대전광역시 서구 관저동 843-16', '대전광역시 유성구 구룡달전로 22',
#        '대전광역시 유성구 대학로 417(21-2 금강유역환경청)', '대전광역시 서구 흑석동 966',
#        '대전광역시 유성구 엑스포로 55', '대전광역시 서구 탄방동 1084',
#        '대전광역시 유성구 노은동로 87번길89(노은동 546)',
#        '대전광역시 유성구 송림로 19번길35(하기동 411-1)', '대전광역시 유성구 노은동 566',
#        '대전광역시 유성구 가정북로 68', '대전광역시 대덕구 목상동 산6-2',
#        '대전광역시 대덕구 석봉로 38번길 55 대덕구보건소', '대전광역시 중구 대사동 145-2',
#        '대전광역시 유성구 교촌동 568-1', '대전광역시 중구 문화로234번길 34',
#        '대전광역시 유성구 월드컵대로 32(월드컵대로 32)',
#        '대전광역시 서구 청사로 189 정부대전청사 후생동 지하주차장 입구 근처',
#        '대전광역시 중구 중앙로 100 (대흥동 499-1)', '대전광역시 서구 상보안윗길 160',
#        '대전광역시 유성구 테크노 9로 35 입구 국기계양대 왼쪽', '대전광역시 동구 대청호수로545번길 1',
#        '대전광역시 유성구 덕명동 513', '대전광역시 유성구 동서대로 621', '대전광역시 서구 도마동 155-16 ',
# ...

# %%
Elec_list_DJ['주소'].str[9:]
# Out:
# 41                   가정로 168 입구 경비실 앞 주차장
# 100                              가수원로 105
# 133                        갈마중로 30번길 15-5
# 134                           갈마동 427-20
# 550                              관저동 1104
#                        ...
# 120980    충정로 21탐구관 지하주차장 1층(77-3 대전보건대학)
# 120981    충정로 21탐구관 지하주차장 1층(77-3 대전보건대학)
# 120982    충정로 21탐구관 지하주차장 1층(77-3 대전보건대학)
# 120983    충정로 21탐구관 지하주차장 1층(77-3 대전보건대학)
# 120992          월드컵대로 301기린빌딩(구암동 614-14)
# Name: 주소, Length: 1332, dtype: object

# %%
# 주소2컬럼을 만들어서 뒷주소가 없는 충전소 필터링
Elec_list_DJ['주소2'] = Elec_list_DJ['주소'].str[9:]
Elec_list_DJ[Elec_list_DJ['주소2'] == '']
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16068\920093381.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Elec_list_DJ['주소2'] = Elec_list_DJ['주소'].str[9:]
#        운영기관           충전소  충전기ID            충전기타입     지역  시군구        주소  \
# 64692  대영채비  도시철도 1호선 판암역      1  DC차데모+AC3상+DC콤보  대전광역시  NaN  대전광역시 동구
# 64693  대영채비  도시철도 1호선 판암역      2             AC완속  대전광역시  NaN  대전광역시 동구
#
#           이용가능시간 이용자 제한 급속충전량   비고 주소2
# 64692  24시간 이용가능   제한없음   NaN  NaN
# 64693  24시간 이용가능   제한없음   NaN  NaN

# %%
# 필터링 된 충전소 두 곳이 동구이므로 시군구에 동구 추가
Elec_list_DJ['시군구'] = Elec_list_DJ['시군구'].fillna('동구')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16068\2250375890.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Elec_list_DJ['시군구'] = Elec_list_DJ['시군구'].fillna('동구')

# %%
Elec_list_DJ.reset_index(drop=True ,inplace=True)

# %%
# 대전광역시 동구 >> 대전광역시 동구 옥천로 지하 162 변경
Elec_list_DJ[Elec_list_DJ['주소2'] == ''].index
# Out:
# Int64Index([905, 906], dtype='int64')

# %%
DJ_index = [905, 906]

# %%
Elec_list_DJ.iloc[DJ_index, -6] = '대전광역시 동구 옥천로 지하 162'

# %%
# 다시 주소2 실행
Elec_list_DJ['주소2'] = Elec_list_DJ['주소'].str[9:]
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16068\2930956023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Elec_list_DJ['주소2'] = Elec_list_DJ['주소'].str[9:]

# %%
# 주소 다 들어간것 확인
Elec_list_DJ[Elec_list_DJ['주소2'] == '']
# Out:
# Empty DataFrame
# Columns: [운영기관, 충전소, 충전기ID, 충전기타입, 지역, 시군구, 주소, 이용가능시간, 이용자 제한, 급속충전량, 비고, 주소2]
# Index: []

# %%
# 시군구 결측치
Elec_list_DJ[Elec_list_DJ['시군구'].isnull()]
# Out:
# Empty DataFrame
# Columns: [운영기관, 충전소, 충전기ID, 충전기타입, 지역, 시군구, 주소, 이용가능시간, 이용자 제한, 급속충전량, 비고, 주소2]
# Index: []

# %%
Elec_list_DJ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1332 entries, 0 to 1331
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   운영기관    1332 non-null   object
#  1   충전소     1332 non-null   object
#  2   충전기ID   1332 non-null   int64
#  3   충전기타입   1332 non-null   object
#  4   지역      1332 non-null   object
#  5   시군구     1332 non-null   object
#  6   주소      1332 non-null   object
#  7   이용가능시간  1266 non-null   object
#  8   이용자 제한  1332 non-null   object
#  9   급속충전량   129 non-null    object
#  10  비고      268 non-null    object
#  11  주소2     1332 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 125.0+ KB

# %% [markdown]
# 제주도

# %%
Elec_list_JEJU = Elec_list[Elec_list['지역'] == '제주특별자치도']

# %%
Elec_list_JEJU = Elec_list_JEJU[Elec_list_JEJU['이용자 제한'] == '제한없음']

# %%
Elec_list_JEJU
# Out:
#                   운영기관         충전소  충전기ID            충전기타입       지역    시군구  \
# 75      환경부(한국자동차환경협회)       ㈜행운식품      1  DC차데모+AC3상+DC콤보  제주특별자치도   제주시
# 210     환경부(한국자동차환경협회)    강정크루즈터미널     21             DC콤보  제주특별자치도  서귀포시
# 211     환경부(한국자동차환경협회)    강정크루즈터미널     22             DC콤보  제주특별자치도  서귀포시
# 241     환경부(한국자동차환경협회)        거문오름      1       DC차데모+AC3상  제주특별자치도   제주시
# 265     환경부(한국자동차환경협회)        건강쉼터     21             DC콤보  제주특별자치도   제주시
# ...                ...         ...    ...              ...      ...    ...
# 114413             씨어스   우도넥스트아일랜드      6             AC완속  제주특별자치도   제주시
# 114414             씨어스   우도넥스트아일랜드      7             AC완속  제주특별자치도   제주시
# 114415             씨어스   우도넥스트아일랜드      8             AC완속  제주특별자치도   제주시
# 114433             씨어스  제주 장애인복지회관      1             AC완속  제주특별자치도   제주시
# 115377            성민기업        킹덤타운      1             AC완속  제주특별자치도  서귀포시
#
#                                                     주소       이용가능시간 이용자 제한  \
# ...

# %%
Elec_list_JEJU.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3930 entries, 75 to 115377
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   운영기관    3930 non-null   object
#  1   충전소     3930 non-null   object
#  2   충전기ID   3930 non-null   int64
#  3   충전기타입   3930 non-null   object
#  4   지역      3930 non-null   object
#  5   시군구     3868 non-null   object
#  6   주소      3930 non-null   object
#  7   이용가능시간  3905 non-null   object
#  8   이용자 제한  3930 non-null   object
#  9   급속충전량   315 non-null    object
#  10  비고      156 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 368.4+ KB

# %%
Elec_list_JEJU[Elec_list_JEJU.duplicated()]  # 제주도 중복X
# Out:
# Empty DataFrame
# Columns: [운영기관, 충전소, 충전기ID, 충전기타입, 지역, 시군구, 주소, 이용가능시간, 이용자 제한, 급속충전량, 비고]
# Index: []

# %%
Elec_list_JEJU['시군구'].unique()
# Out:
# array(['제주시 ', '서귀포시 ', nan], dtype=object)

# %%
# 주소2컬럼을 만들어서 뒷주소가 없는 충전소 필터링
Elec_list_JEJU['주소2'] = Elec_list_JEJU['주소'].str[12:]
a = Elec_list_JEJU[Elec_list_JEJU['주소2'] == '']

# %%
# 제주도 주소 넣어주기
addr_jeju = ['제주특별자치도 제주시 영평동 896-2',
'제주특별자치도 제주시 영평동 896-2',
'제주특별자치도 제주시 영평동 896-2',
'제주특별자치도 제주시 영평동 896-2',
'제주특별자치도 제주시 영평동 896-2',
'제주특별자치도 제주시 애월읍 소길리 산 19',
'제주특별자치도 제주시 애월읍 소길리 산 19',
'제주특별자치도 제주시 애월읍 소길리 산 19',
'제주특별자치도 제주시 애월읍 소길리 산 19',
'제주특별자치도 제주시 애월읍 소길리 산 19',
'제주특별자치도 제주시 구좌읍 송당리 353-2',
'제주특별자치도 제주시 구좌읍 송당리 353-2',
'제주특별자치도 제주시 구좌읍 송당리 353-2',
'제주특별자치도 제주시 구좌읍 송당리 353-2',
'제주특별자치도 제주시 구좌읍 송당리 353-2',
'제주특별자치도 제주시 구좌읍 월정리 1400-33',
'제주특별자치도 제주시 구좌읍 월정리 1400-33',
'제주특별자치도 제주시 구좌읍 월정리 1400-33',
'제주특별자치도 제주시 구좌읍 월정리 1400-33',
'제주특별자치도 제주시 제주특별자치도 제주시 한경면 조수리 90',
'제주특별자치도 제주시 제주특별자치도 제주시 한경면 조수리 90',
'제주특별자치도 제주시 제주특별자치도 제주시 한경면 조수리 90',
'제주특별자치도 서귀포시 성읍리 2197-12',
'제주특별자치도 서귀포시 성읍리 2197-12',
'제주특별자치도 서귀포시 남원읍 신례리 2075-4 주차장',
'제주특별자치도 서귀포시 남원읍 신례리 2075-4 주차장',
'제주특별자치도 서귀포시 대정읍 가파리 427',
'제주특별자치도 제주시 애월읍 하가리 1589-2',
'제주특별자치도 제주시 연동 322-8',
'제주특별자치도 제주시 연동 322-8',
'제주특별자치도 제주시 연동 322-8',
'제주특별자치도 제주시 연동 322-8',
'제주특별자치도 제주시 연동 322-8',
'제주특별자치도 제주시 연동 322-8',
'제주특별자치도 제주시 연동 322-8',
'제주특별자치도 제주시 연동 322-8',
'제주특별자치도 제주시 연동 322-8',
'제주특별자치도 제주시 구좌읍 동복리 1713-1',
'제주특별자치도 제주시 화북일동 14-1',
'제주특별자치도 제주시 일도2동 510번지',
'제주특별자치도 제주시 일도2동 510번지',
'제주특별자치도 제주시 일도2동 510번지',
'제주특별자치도 제주시 일도2동 510번지',
'제주특별자치도 제주시 일도2동 510번지',
'제주특별자치도 제주시 일도2동 510번지',
'제주특별자치도 제주시 일도2동 510번지',
'제주특별자치도 제주시 일도2동 510번지',
'제주특별자치도 제주시 일도2동 510번지',
'제주특별자치도 제주시 일도2동 510번지',
'제주특별자치도 서귀포시 대정읍 가파리 373-2',
'제주특별자치도 서귀포시 서귀동 28-3',
'제주특별자치도 제주시 도남동 755-1',
'제주특별자치도 제주시 도남동 755-1',
'제주특별자치도 제주시 아라2동 941-7(현인빌라 맞은편)',
'제주특별자치도 서귀포시 남원읍 의귀리 1515',
'제주특별자치도 서귀포시 남원읍 의귀리 1515',
'제주특별자치도 제주시 외도일동 173-1',
'제주특별자치도 제주시 외도일동 173-1',
'제주특별자치도 제주시 노형동 2512-1(노형세기7차아파트 인근)',
'제주특별자치도 서귀포시 표선면 표선리 711(표선면사무소 옆 공영주차장)',
'제주특별자치도 제주시 화북일동 11-7',
'제주특별자치도 제주시 화북일동 11-7']

# %%
# 인덱스 재지정
Elec_list_JEJU.reset_index(drop=True ,inplace=True)

# %%
# 주소 없는 것들
Elec_list_JEJU[Elec_list_JEJU['주소2'] == ''].index
# Out:
# Int64Index([ 415,  416,  417,  418,  419,  420,  421,  422,  423,  424,  635,
#              636,  637,  638,  639,  665,  666,  667,  668,  723,  724,  725,
#              770,  771, 1276, 1277, 2147, 2217, 2230, 2231, 2232, 2233, 2234,
#             2235, 2236, 2237, 2238, 2241, 2265, 2267, 2268, 2269, 2270, 2271,
#             2272, 2273, 2274, 2275, 2276, 2301, 2307, 2423, 2424, 2437, 2498,
#             2499, 2620, 2621, 2661, 2692, 2738, 2739],
#            dtype='int64')

# %%
JEJU_index = [415,  416,  417,  418,  419,  420,  421,  422,  423,  424,  635, 636,  637,  638,  639,  665,  666,  667,  668,  723,  724,  725, 770,  771, 1276, 1277, 2147, 2217, 2230, 2231, 2232, 2233, 2234, 2235, 2236, 2237, 2238, 2241, 2265, 2267, 2268, 2269, 2270, 2271, 2272, 2273, 2274, 2275, 2276, 2301, 2307, 2423, 2424, 2437, 2498, 2499, 2620, 2621, 2661, 2692, 2738, 2739]

# %%
Elec_list_JEJU.iloc[JEJU_index, -6] = addr_jeju

# %%
Elec_list_JEJU['주소2'] = Elec_list_JEJU['주소'].str[12:]
Elec_list_JEJU['주소2']
# Out:
# 0                            조천읍 함덕리 906번지
# 1                                  말질로 261
# 2                                  말질로 261
# 3           조천읍 선교로 569-36, 소형주차장(선흘리 478)
# 4                           한경면 두모리 2962-1
#                        ...
# 3925    우도면 우도해안길 32-24우도넥스트아일랜드(연평리 1707)
# 3926    우도면 우도해안길 32-24우도넥스트아일랜드(연평리 1707)
# 3927    우도면 우도해안길 32-24우도넥스트아일랜드(연평리 1707)
# 3928        서광로27길 16장애인 복지회관(이도일동 1660-6)
# 3929         표선면 가시로 349-15주차장(세화리 2177-9)
# Name: 주소2, Length: 3930, dtype: object

# %%
# 주소 다 들어갔는지 확인
Elec_list_DJ[Elec_list_DJ['주소2'] == '']
# Out:
# Empty DataFrame
# Columns: [운영기관, 충전소, 충전기ID, 충전기타입, 지역, 시군구, 주소, 이용가능시간, 이용자 제한, 급속충전량, 비고, 주소2]
# Index: []

# %%
# 주소에서 시군구 추출하여 컬럼에 추가
Elec_list_JEJU['시군구'] = Elec_list_JEJU['주소'].str.split(' ', expand=True)[1]

# %%
Elec_list_JEJU[Elec_list_JEJU['시군구'].isnull()]
# Out:
# Empty DataFrame
# Columns: [운영기관, 충전소, 충전기ID, 충전기타입, 지역, 시군구, 주소, 이용가능시간, 이용자 제한, 급속충전량, 비고, 주소2]
# Index: []

# %%
Elec_list_JEJU.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3930 entries, 0 to 3929
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   운영기관    3930 non-null   object
#  1   충전소     3930 non-null   object
#  2   충전기ID   3930 non-null   int64
#  3   충전기타입   3930 non-null   object
#  4   지역      3930 non-null   object
#  5   시군구     3930 non-null   object
#  6   주소      3930 non-null   object
#  7   이용가능시간  3905 non-null   object
#  8   이용자 제한  3930 non-null   object
#  9   급속충전량   315 non-null    object
#  10  비고      156 non-null    object
#  11  주소2     3930 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 368.6+ KB

# %%
df_all = pd.concat([Elec_list_DJ,Elec_list_JEJU])

# %%
df_all.to_csv('대전_제주 전기차 충전소.csv', index=False)
