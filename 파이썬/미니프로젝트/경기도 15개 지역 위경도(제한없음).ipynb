# %%
import pandas as pd

# %%
df = pd.read_csv('./경기 15개 지역 위경도.csv')

# %%
df
# Out:
#       Unnamed: 0            운영기관                      충전소  충전기ID  \
# 0              0  환경부(한국자동차환경협회)                  KH양주휴게소      1
# 1              1  환경부(한국자동차환경협회)  S-oil 셀프 신현주유소(영광셀프주유소)      1
# 2              2  환경부(한국자동차환경협회)               VIC마켓 킨텍스점      1
# 3              3  환경부(한국자동차환경협회)               VIC마켓 킨텍스점      2
# 4              4  환경부(한국자동차환경협회)          ㈜디에스 화랑포 셀프주유소      91
# ...          ...             ...                      ...    ...
# 4205       11320          한국전자금융             의정부 호원신일엘리시움      3
# 4206       11342           한화솔루션                  파주유앤비빌딩      1
# 4207       11343           한화솔루션                  파주유앤비빌딩      2
# 4208       11344           한화솔루션                  파주유앤비빌딩      3
# 4209       11345           한화솔루션                  파주유앤비빌딩      4
#
#                 충전기타입   지역   시군구                         주소 이용자 제한  \
# 0     DC차데모+AC3상+DC콤보  경기도   양주시  경기도 양주시 장흥면 서울외곽순환고속도로 58   제한없음
# ...

# %%
df['lat'].unique()
# Out:
# array([ 0.        , 37.41403898, 37.66727315, ..., 37.75036935,
#        37.70945854, 37.7557869 ])

# %%
df2 = df[df['lat'] == 0.000000]

# %%
# 제한없음 위경도 결측치..
df2
# Out:
#       Unnamed: 0            운영기관          충전소  충전기ID            충전기타입   지역  \
# 0              0  환경부(한국자동차환경협회)      KH양주휴게소      1  DC차데모+AC3상+DC콤보  경기도
# 7              7  환경부(한국자동차환경협회)       ㈜연세에너지     91             DC콤보  경기도
# 28            28  환경부(한국자동차환경협회)  경기 갈매동구릉영업소      1             DC콤보  경기도
# 74            80  환경부(한국자동차환경협회)  구리휴게소(외측방향)      1  DC차데모+AC3상+DC콤보  경기도
# 78            91  환경부(한국자동차환경협회)      금촌하수처리장      1             DC콤보  경기도
# ...          ...             ...          ...    ...              ...  ...
# 4137       11197            이지차저  e편한세상광주역3단지      2             AC완속  경기도
# 4138       11198            이지차저  e편한세상광주역3단지      3             AC완속  경기도
# 4139       11199            이지차저  e편한세상광주역3단지      4             AC완속  경기도
# 4140       11200            이지차저  e편한세상광주역3단지      5             AC완속  경기도
# 4141       11201            이지차저  e편한세상광주역3단지      6             AC완속  경기도
#
#       시군구                                   주소 이용자 제한  \
# ...
